# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 데이터준비

# %%
data_path = os.getenv('HOME')+'/aiffel/conditional_generation/data/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
# 1000장중 6장 랜덤출력
plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(1000)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
# 첫번째 이미지의 크기확인
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
# augmentation 적용

from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
# augmentation 적용 확인

from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %%
from tensorflow.keras import layers, Input, Model

# class EncodeBlock(layers.Layer):
#     def __init__(self, n_filters, use_bn=True):
#         super(EncodeBlock, self).__init__()
#         self.use_bn = use_bn       
#         self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
#         self.batchnorm = layers.BatchNormalization()
#         self.lrelu= layers.LeakyReLU(0.2)

#     def call(self, x):
#         x = self.conv(x)
#         if self.use_bn:
#             x = self.batchnorm(x)
#         return self.lrelu(x)

# %% [markdown]
# ## U-net generator 구현

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# ## Discriminatior 구현

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
# (256,256,3)input -> (30,30)output
x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ## 모델학습

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 30

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.9118
# L1_loss:0.3666
# Discriminator_loss:1.1841
#
# EPOCH[1] - STEP[20]
# Generator_loss:0.8990
# L1_loss:0.3358
# Discriminator_loss:1.2022
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.1715
# L1_loss:0.3062
# Discriminator_loss:0.8623
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.4865
# L1_loss:0.2230
# Discriminator_loss:0.9480
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.5452
# L1_loss:0.2365
# Discriminator_loss:0.7355
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.8892
# L1_loss:0.2943
# Discriminator_loss:0.5786
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.2688
# L1_loss:0.2860
# Discriminator_loss:0.8739
#
# EPOCH[1] - STEP[80]
# Generator_loss:1.7393
# L1_loss:0.2033
# Discriminator_loss:0.4602
#
# EPOCH[1] - STEP[90]
# Generator_loss:1.8143
# L1_loss:0.2511
# Discriminator_loss:1.3078
#
# EPOCH[1] - STEP[100]
# Generator_loss:2.2795
# L1_loss:0.2546
# Discriminator_loss:0.9553
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.7541
# L1_loss:0.2453
# Discriminator_loss:0.7518
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.0555
# L1_loss:0.2163
# Discriminator_loss:0.9235
#
# EPOCH[1] - STEP[130]
# Generator_loss:2.5451
# L1_loss:0.1985
# Discriminator_loss:1.0216
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.8050
# L1_loss:0.1936
# Discriminator_loss:1.1368
#
# EPOCH[1] - STEP[150]
# Generator_loss:1.4443
# L1_loss:0.2556
# Discriminator_loss:0.4320
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.6561
# L1_loss:0.2167
# Discriminator_loss:0.6416
#
# EPOCH[1] - STEP[170]
# Generator_loss:2.0180
# L1_loss:0.2115
# Discriminator_loss:0.9766
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.8838
# L1_loss:0.2381
# Discriminator_loss:0.4428
#
# EPOCH[1] - STEP[190]
# Generator_loss:1.9314
# L1_loss:0.1965
# Discriminator_loss:0.8506
#
# EPOCH[1] - STEP[200]
# Generator_loss:2.3693
# L1_loss:0.1960
# Discriminator_loss:1.3083
#
# EPOCH[1] - STEP[210]
# Generator_loss:1.5692
# L1_loss:0.1935
# Discriminator_loss:0.5264
#
# EPOCH[1] - STEP[220]
# Generator_loss:1.7259
# L1_loss:0.2037
# Discriminator_loss:1.1507
#
# EPOCH[1] - STEP[230]
# Generator_loss:2.9155
# L1_loss:0.2370
# Discriminator_loss:0.2588
#
# EPOCH[1] - STEP[240]
# Generator_loss:2.1438
# L1_loss:0.2853
# Discriminator_loss:0.2679
#
# EPOCH[1] - STEP[250]
# Generator_loss:2.1854
# L1_loss:0.2270
# Discriminator_loss:0.3318
#
# EPOCH[2] - STEP[10]
# Generator_loss:1.9140
# L1_loss:0.2302
# Discriminator_loss:0.5155
#
# EPOCH[2] - STEP[20]
# Generator_loss:2.0634
# L1_loss:0.2548
# Discriminator_loss:0.5209
#
# EPOCH[2] - STEP[30]
# Generator_loss:1.6543
# L1_loss:0.1670
# Discriminator_loss:1.2344
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.5033
# L1_loss:0.2436
# Discriminator_loss:0.8698
#
# EPOCH[2] - STEP[50]
# Generator_loss:0.4171
# L1_loss:0.2085
# Discriminator_loss:1.5294
#
# EPOCH[2] - STEP[60]
# Generator_loss:0.7327
# L1_loss:0.2065
# Discriminator_loss:0.8814
#
# EPOCH[2] - STEP[70]
# Generator_loss:2.2654
# L1_loss:0.3052
# Discriminator_loss:1.0123
#
# EPOCH[2] - STEP[80]
# Generator_loss:0.9036
# L1_loss:0.2117
# Discriminator_loss:0.9513
#
# EPOCH[2] - STEP[90]
# Generator_loss:2.2073
# L1_loss:0.2598
# Discriminator_loss:0.4707
#
# EPOCH[2] - STEP[100]
# Generator_loss:0.9258
# L1_loss:0.2359
# Discriminator_loss:0.8482
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.4218
# L1_loss:0.2407
# Discriminator_loss:0.4279
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.7718
# L1_loss:0.1882
# Discriminator_loss:0.7777
#
# EPOCH[2] - STEP[130]
# Generator_loss:2.3347
# L1_loss:0.2264
# Discriminator_loss:0.3684
#
# EPOCH[2] - STEP[140]
# Generator_loss:2.3460
# L1_loss:0.2116
# Discriminator_loss:0.8431
#
# EPOCH[2] - STEP[150]
# Generator_loss:2.7302
# L1_loss:0.2208
# Discriminator_loss:0.2976
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.1355
# L1_loss:0.1947
# Discriminator_loss:0.6439
#
# EPOCH[2] - STEP[170]
# Generator_loss:1.1636
# L1_loss:0.2040
# Discriminator_loss:0.6869
#
# EPOCH[2] - STEP[180]
# Generator_loss:1.4313
# L1_loss:0.2041
# Discriminator_loss:0.4410
#
# EPOCH[2] - STEP[190]
# Generator_loss:2.6951
# L1_loss:0.2163
# Discriminator_loss:0.9783
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.7289
# L1_loss:0.2579
# Discriminator_loss:0.5323
#
# EPOCH[2] - STEP[210]
# Generator_loss:2.4597
# L1_loss:0.2135
# Discriminator_loss:0.9827
#
# EPOCH[2] - STEP[220]
# Generator_loss:2.6802
# L1_loss:0.1974
# Discriminator_loss:0.8621
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.1751
# L1_loss:0.2003
# Discriminator_loss:0.2665
#
# EPOCH[2] - STEP[240]
# Generator_loss:2.4719
# L1_loss:0.2134
# Discriminator_loss:2.1273
#
# EPOCH[2] - STEP[250]
# Generator_loss:1.6781
# L1_loss:0.1980
# Discriminator_loss:0.5564
#
# EPOCH[3] - STEP[10]
# Generator_loss:1.1870
# L1_loss:0.1900
# Discriminator_loss:1.2252
#
# EPOCH[3] - STEP[20]
# Generator_loss:1.6982
# L1_loss:0.1974
# Discriminator_loss:0.8549
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.5928
# L1_loss:0.2213
# Discriminator_loss:0.3689
#
# EPOCH[3] - STEP[40]
# Generator_loss:2.1015
# L1_loss:0.1742
# Discriminator_loss:0.7445
#
# EPOCH[3] - STEP[50]
# Generator_loss:3.0091
# L1_loss:0.1807
# Discriminator_loss:1.7992
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.0152
# L1_loss:0.1922
# Discriminator_loss:1.1696
#
# EPOCH[3] - STEP[70]
# Generator_loss:1.5196
# L1_loss:0.2364
# Discriminator_loss:0.8756
#
# EPOCH[3] - STEP[80]
# Generator_loss:0.9077
# L1_loss:0.2467
# Discriminator_loss:0.9262
#
# EPOCH[3] - STEP[90]
# Generator_loss:2.1641
# L1_loss:0.2294
# Discriminator_loss:1.3437
#
# EPOCH[3] - STEP[100]
# Generator_loss:0.9953
# L1_loss:0.1827
# Discriminator_loss:0.7048
#
# EPOCH[3] - STEP[110]
# Generator_loss:3.0518
# L1_loss:0.1495
# Discriminator_loss:1.6760
#
# EPOCH[3] - STEP[120]
# Generator_loss:2.1236
# L1_loss:0.2317
# Discriminator_loss:0.5065
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.4305
# L1_loss:0.2365
# Discriminator_loss:0.7212
#
# EPOCH[3] - STEP[140]
# Generator_loss:2.1396
# L1_loss:0.2390
# Discriminator_loss:0.2506
#
# EPOCH[3] - STEP[150]
# Generator_loss:2.3325
# L1_loss:0.2157
# Discriminator_loss:0.4704
#
# EPOCH[3] - STEP[160]
# Generator_loss:2.8797
# L1_loss:0.2047
# Discriminator_loss:0.8802
#
# EPOCH[3] - STEP[170]
# Generator_loss:1.7794
# L1_loss:0.1946
# Discriminator_loss:0.9872
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.1370
# L1_loss:0.2465
# Discriminator_loss:0.3564
#
# EPOCH[3] - STEP[190]
# Generator_loss:0.6329
# L1_loss:0.1751
# Discriminator_loss:1.1054
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.2045
# L1_loss:0.2180
# Discriminator_loss:0.6721
#
# EPOCH[3] - STEP[210]
# Generator_loss:2.9718
# L1_loss:0.1810
# Discriminator_loss:1.7385
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.0573
# L1_loss:0.1812
# Discriminator_loss:0.9830
#
# EPOCH[3] - STEP[230]
# Generator_loss:2.5103
# L1_loss:0.2000
# Discriminator_loss:0.6628
#
# EPOCH[3] - STEP[240]
# Generator_loss:2.2309
# L1_loss:0.1960
# Discriminator_loss:0.5590
#
# EPOCH[3] - STEP[250]
# Generator_loss:1.3291
# L1_loss:0.1845
# Discriminator_loss:0.7319
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.9884
# L1_loss:0.1869
# Discriminator_loss:1.1328
#
# EPOCH[4] - STEP[20]
# Generator_loss:0.7449
# L1_loss:0.1720
# Discriminator_loss:0.9666
#
# EPOCH[4] - STEP[30]
# Generator_loss:2.6774
# L1_loss:0.1813
# Discriminator_loss:1.4822
#
# EPOCH[4] - STEP[40]
# Generator_loss:2.6389
# L1_loss:0.2014
# Discriminator_loss:0.2740
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.4594
# L1_loss:0.1611
# Discriminator_loss:1.5187
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.2132
# L1_loss:0.2003
# Discriminator_loss:0.8380
#
# EPOCH[4] - STEP[70]
# Generator_loss:2.0677
# L1_loss:0.2246
# Discriminator_loss:0.7919
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.7165
# L1_loss:0.2499
# Discriminator_loss:0.4834
#
# EPOCH[4] - STEP[90]
# Generator_loss:2.5462
# L1_loss:0.1992
# Discriminator_loss:1.1147
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.7386
# L1_loss:0.1675
# Discriminator_loss:0.7681
#
# EPOCH[4] - STEP[110]
# Generator_loss:0.5994
# L1_loss:0.2028
# Discriminator_loss:1.4008
#
# EPOCH[4] - STEP[120]
# Generator_loss:1.2164
# L1_loss:0.1902
# Discriminator_loss:0.6939
#
# EPOCH[4] - STEP[130]
# Generator_loss:1.4565
# L1_loss:0.2151
# Discriminator_loss:0.4968
#
# EPOCH[4] - STEP[140]
# Generator_loss:1.6376
# L1_loss:0.1531
# Discriminator_loss:1.1698
#
# EPOCH[4] - STEP[150]
# Generator_loss:2.0011
# L1_loss:0.2474
# Discriminator_loss:0.8707
#
# EPOCH[4] - STEP[160]
# Generator_loss:2.4958
# L1_loss:0.1846
# Discriminator_loss:1.5584
#
# EPOCH[4] - STEP[170]
# Generator_loss:2.4565
# L1_loss:0.2003
# Discriminator_loss:1.5039
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.8765
# L1_loss:0.1993
# Discriminator_loss:0.6737
#
# EPOCH[4] - STEP[190]
# Generator_loss:1.5233
# L1_loss:0.1980
# Discriminator_loss:0.5529
#
# EPOCH[4] - STEP[200]
# Generator_loss:2.4284
# L1_loss:0.1710
# Discriminator_loss:1.3462
#
# EPOCH[4] - STEP[210]
# Generator_loss:2.5269
# L1_loss:0.2217
# Discriminator_loss:0.7849
#
# EPOCH[4] - STEP[220]
# Generator_loss:2.3369
# L1_loss:0.1771
# Discriminator_loss:1.2971
#
# EPOCH[4] - STEP[230]
# Generator_loss:1.5825
# L1_loss:0.1835
# Discriminator_loss:0.7450
#
# EPOCH[4] - STEP[240]
# Generator_loss:1.8853
# L1_loss:0.2034
# Discriminator_loss:0.5209
#
# EPOCH[4] - STEP[250]
# Generator_loss:0.6544
# L1_loss:0.2099
# Discriminator_loss:1.2531
#
# EPOCH[5] - STEP[10]
# Generator_loss:2.1460
# L1_loss:0.1954
# Discriminator_loss:0.9198
#
# EPOCH[5] - STEP[20]
# Generator_loss:0.8837
# L1_loss:0.1597
# Discriminator_loss:1.3288
#
# EPOCH[5] - STEP[30]
# Generator_loss:2.8931
# L1_loss:0.1715
# Discriminator_loss:1.5653
#
# EPOCH[5] - STEP[40]
# Generator_loss:2.7530
# L1_loss:0.1932
# Discriminator_loss:1.4786
#
# EPOCH[5] - STEP[50]
# Generator_loss:1.3453
# L1_loss:0.1789
# Discriminator_loss:0.8487
#
# EPOCH[5] - STEP[60]
# Generator_loss:2.0721
# L1_loss:0.1715
# Discriminator_loss:0.6926
#
# EPOCH[5] - STEP[70]
# Generator_loss:2.5431
# L1_loss:0.1879
# Discriminator_loss:0.4736
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.9177
# L1_loss:0.2198
# Discriminator_loss:0.4773
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.2983
# L1_loss:0.2112
# Discriminator_loss:0.7993
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.9460
# L1_loss:0.1755
# Discriminator_loss:0.7947
#
# EPOCH[5] - STEP[110]
# Generator_loss:1.0124
# L1_loss:0.1874
# Discriminator_loss:0.7209
#
# EPOCH[5] - STEP[120]
# Generator_loss:0.9557
# L1_loss:0.1451
# Discriminator_loss:1.4142
#
# EPOCH[5] - STEP[130]
# Generator_loss:2.9223
# L1_loss:0.1941
# Discriminator_loss:1.3836
#
# EPOCH[5] - STEP[140]
# Generator_loss:0.3392
# L1_loss:0.2159
# Discriminator_loss:1.5812
#
# EPOCH[5] - STEP[150]
# Generator_loss:2.7375
# L1_loss:0.1464
# Discriminator_loss:1.5865
#
# EPOCH[5] - STEP[160]
# Generator_loss:3.2487
# L1_loss:0.2262
# Discriminator_loss:0.9025
#
# EPOCH[5] - STEP[170]
# Generator_loss:2.0963
# L1_loss:0.2053
# Discriminator_loss:0.6828
#
# EPOCH[5] - STEP[180]
# Generator_loss:0.9573
# L1_loss:0.2266
# Discriminator_loss:0.9149
#
# EPOCH[5] - STEP[190]
# Generator_loss:1.6020
# L1_loss:0.2080
# Discriminator_loss:0.4232
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.8733
# L1_loss:0.1882
# Discriminator_loss:0.5895
#
# EPOCH[5] - STEP[210]
# Generator_loss:1.4117
# L1_loss:0.1521
# Discriminator_loss:0.9525
#
# EPOCH[5] - STEP[220]
# Generator_loss:2.8796
# L1_loss:0.1632
# Discriminator_loss:1.8484
#
# EPOCH[5] - STEP[230]
# Generator_loss:3.1854
# L1_loss:0.1931
# Discriminator_loss:1.3672
#
# EPOCH[5] - STEP[240]
# Generator_loss:0.9255
# L1_loss:0.2049
# Discriminator_loss:0.7982
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.5134
# L1_loss:0.2243
# Discriminator_loss:0.4975
#
# EPOCH[6] - STEP[10]
# Generator_loss:2.3935
# L1_loss:0.1663
# Discriminator_loss:1.1589
#
# EPOCH[6] - STEP[20]
# Generator_loss:2.2601
# L1_loss:0.1801
# Discriminator_loss:0.5843
#
# EPOCH[6] - STEP[30]
# Generator_loss:0.7196
# L1_loss:0.1726
# Discriminator_loss:1.0659
#
# EPOCH[6] - STEP[40]
# Generator_loss:1.5883
# L1_loss:0.1875
# Discriminator_loss:0.6306
#
# EPOCH[6] - STEP[50]
# Generator_loss:2.0235
# L1_loss:0.2093
# Discriminator_loss:0.3163
#
# EPOCH[6] - STEP[60]
# Generator_loss:2.2687
# L1_loss:0.1643
# Discriminator_loss:0.4154
#
# EPOCH[6] - STEP[70]
# Generator_loss:2.2558
# L1_loss:0.2040
# Discriminator_loss:0.4898
#
# EPOCH[6] - STEP[80]
# Generator_loss:1.4274
# L1_loss:0.1786
# Discriminator_loss:1.5058
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.3099
# L1_loss:0.1873
# Discriminator_loss:0.6027
#
# EPOCH[6] - STEP[100]
# Generator_loss:3.3815
# L1_loss:0.1693
# Discriminator_loss:2.0971
#
# EPOCH[6] - STEP[110]
# Generator_loss:0.2069
# L1_loss:0.1884
# Discriminator_loss:2.0182
#
# EPOCH[6] - STEP[120]
# Generator_loss:2.1159
# L1_loss:0.2045
# Discriminator_loss:0.6076
#
# EPOCH[6] - STEP[130]
# Generator_loss:2.2379
# L1_loss:0.2118
# Discriminator_loss:0.5233
#
# EPOCH[6] - STEP[140]
# Generator_loss:1.5328
# L1_loss:0.1984
# Discriminator_loss:0.4725
#
# EPOCH[6] - STEP[150]
# Generator_loss:2.6824
# L1_loss:0.2175
# Discriminator_loss:0.4354
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.2253
# L1_loss:0.1832
# Discriminator_loss:0.7119
#
# EPOCH[6] - STEP[170]
# Generator_loss:2.3122
# L1_loss:0.2011
# Discriminator_loss:0.3542
#
# EPOCH[6] - STEP[180]
# Generator_loss:2.0127
# L1_loss:0.2001
# Discriminator_loss:1.0879
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.5228
# L1_loss:0.1913
# Discriminator_loss:0.5289
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.9367
# L1_loss:0.1640
# Discriminator_loss:0.8308
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.1190
# L1_loss:0.2590
# Discriminator_loss:0.6458
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.1693
# L1_loss:0.1888
# Discriminator_loss:0.9993
#
# EPOCH[6] - STEP[230]
# Generator_loss:1.8999
# L1_loss:0.1742
# Discriminator_loss:0.4684
#
# EPOCH[6] - STEP[240]
# Generator_loss:1.1284
# L1_loss:0.1960
# Discriminator_loss:0.5666
#
# EPOCH[6] - STEP[250]
# Generator_loss:2.0358
# L1_loss:0.1737
# Discriminator_loss:0.5191
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.0918
# L1_loss:0.2303
# Discriminator_loss:0.5249
#
# EPOCH[7] - STEP[20]
# Generator_loss:1.9635
# L1_loss:0.1583
# Discriminator_loss:0.7065
#
# EPOCH[7] - STEP[30]
# Generator_loss:2.6721
# L1_loss:0.2536
# Discriminator_loss:0.5380
#
# EPOCH[7] - STEP[40]
# Generator_loss:1.4257
# L1_loss:0.1929
# Discriminator_loss:0.5935
#
# EPOCH[7] - STEP[50]
# Generator_loss:1.5703
# L1_loss:0.2243
# Discriminator_loss:0.5071
#
# EPOCH[7] - STEP[60]
# Generator_loss:0.8473
# L1_loss:0.1957
# Discriminator_loss:0.8349
#
# EPOCH[7] - STEP[70]
# Generator_loss:1.8050
# L1_loss:0.1854
# Discriminator_loss:0.5521
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.5435
# L1_loss:0.1461
# Discriminator_loss:0.7866
#
# EPOCH[7] - STEP[90]
# Generator_loss:0.2564
# L1_loss:0.1601
# Discriminator_loss:2.0540
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.9538
# L1_loss:0.1841
# Discriminator_loss:0.4857
#
# EPOCH[7] - STEP[110]
# Generator_loss:0.8807
# L1_loss:0.2325
# Discriminator_loss:0.7075
#
# EPOCH[7] - STEP[120]
# Generator_loss:1.0950
# L1_loss:0.1611
# Discriminator_loss:0.7348
#
# EPOCH[7] - STEP[130]
# Generator_loss:3.1318
# L1_loss:0.1813
# Discriminator_loss:0.6246
#
# EPOCH[7] - STEP[140]
# Generator_loss:1.4108
# L1_loss:0.1642
# Discriminator_loss:1.1288
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.5129
# L1_loss:0.1660
# Discriminator_loss:0.6936
#
# EPOCH[7] - STEP[160]
# Generator_loss:1.4929
# L1_loss:0.1667
# Discriminator_loss:0.5187
#
# EPOCH[7] - STEP[170]
# Generator_loss:1.6976
# L1_loss:0.2149
# Discriminator_loss:0.3715
#
# EPOCH[7] - STEP[180]
# Generator_loss:2.1554
# L1_loss:0.2131
# Discriminator_loss:0.3602
#
# EPOCH[7] - STEP[190]
# Generator_loss:3.3116
# L1_loss:0.1834
# Discriminator_loss:1.0651
#
# EPOCH[7] - STEP[200]
# Generator_loss:2.0625
# L1_loss:0.2396
# Discriminator_loss:0.6070
#
# EPOCH[7] - STEP[210]
# Generator_loss:3.5617
# L1_loss:0.1743
# Discriminator_loss:1.6574
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.4421
# L1_loss:0.1587
# Discriminator_loss:0.8509
#
# EPOCH[7] - STEP[230]
# Generator_loss:1.0050
# L1_loss:0.1573
# Discriminator_loss:0.6978
#
# EPOCH[7] - STEP[240]
# Generator_loss:0.6151
# L1_loss:0.1553
# Discriminator_loss:1.0929
#
# EPOCH[7] - STEP[250]
# Generator_loss:1.6175
# L1_loss:0.1814
# Discriminator_loss:0.4441
#
# EPOCH[8] - STEP[10]
# Generator_loss:2.5123
# L1_loss:0.1655
# Discriminator_loss:1.1132
#
# EPOCH[8] - STEP[20]
# Generator_loss:0.8069
# L1_loss:0.2237
# Discriminator_loss:0.8521
#
# EPOCH[8] - STEP[30]
# Generator_loss:0.5849
# L1_loss:0.1710
# Discriminator_loss:1.1632
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.7391
# L1_loss:0.1545
# Discriminator_loss:0.8608
#
# EPOCH[8] - STEP[50]
# Generator_loss:0.8278
# L1_loss:0.1977
# Discriminator_loss:1.1006
#
# EPOCH[8] - STEP[60]
# Generator_loss:2.8839
# L1_loss:0.1816
# Discriminator_loss:1.3438
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.2454
# L1_loss:0.1767
# Discriminator_loss:0.5641
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.1274
# L1_loss:0.1797
# Discriminator_loss:0.7454
#
# EPOCH[8] - STEP[90]
# Generator_loss:0.8364
# L1_loss:0.2126
# Discriminator_loss:1.6490
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.2833
# L1_loss:0.2371
# Discriminator_loss:0.3501
#
# EPOCH[8] - STEP[110]
# Generator_loss:2.3280
# L1_loss:0.1976
# Discriminator_loss:0.5984
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.8235
# L1_loss:0.1780
# Discriminator_loss:1.4624
#
# EPOCH[8] - STEP[130]
# Generator_loss:2.9277
# L1_loss:0.1783
# Discriminator_loss:1.1655
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.6462
# L1_loss:0.1565
# Discriminator_loss:1.1834
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.4076
# L1_loss:0.1874
# Discriminator_loss:0.6019
#
# EPOCH[8] - STEP[160]
# Generator_loss:2.0417
# L1_loss:0.1524
# Discriminator_loss:0.9502
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.7870
# L1_loss:0.1615
# Discriminator_loss:1.1016
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.3356
# L1_loss:0.1778
# Discriminator_loss:0.7668
#
# EPOCH[8] - STEP[190]
# Generator_loss:1.4865
# L1_loss:0.1912
# Discriminator_loss:0.8926
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.4598
# L1_loss:0.2063
# Discriminator_loss:0.5552
#
# EPOCH[8] - STEP[210]
# Generator_loss:1.8420
# L1_loss:0.1835
# Discriminator_loss:1.4706
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.3176
# L1_loss:0.2017
# Discriminator_loss:0.3960
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.7782
# L1_loss:0.1718
# Discriminator_loss:0.4817
#
# EPOCH[8] - STEP[240]
# Generator_loss:0.2334
# L1_loss:0.1767
# Discriminator_loss:1.7902
#
# EPOCH[8] - STEP[250]
# Generator_loss:0.3193
# L1_loss:0.1885
# Discriminator_loss:1.7504
#
# EPOCH[9] - STEP[10]
# Generator_loss:0.4878
# L1_loss:0.2170
# Discriminator_loss:1.2003
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.1702
# L1_loss:0.1524
# Discriminator_loss:0.8110
#
# EPOCH[9] - STEP[30]
# Generator_loss:2.4107
# L1_loss:0.1839
# Discriminator_loss:0.8548
#
# EPOCH[9] - STEP[40]
# Generator_loss:0.8675
# L1_loss:0.1477
# Discriminator_loss:0.8453
#
# EPOCH[9] - STEP[50]
# Generator_loss:1.8972
# L1_loss:0.1802
# Discriminator_loss:0.8568
#
# EPOCH[9] - STEP[60]
# Generator_loss:3.7551
# L1_loss:0.1787
# Discriminator_loss:1.2061
#
# EPOCH[9] - STEP[70]
# Generator_loss:1.9706
# L1_loss:0.1634
# Discriminator_loss:0.8370
#
# EPOCH[9] - STEP[80]
# Generator_loss:2.2988
# L1_loss:0.1979
# Discriminator_loss:0.8385
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.3492
# L1_loss:0.1735
# Discriminator_loss:0.4605
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.0443
# L1_loss:0.1857
# Discriminator_loss:0.6662
#
# EPOCH[9] - STEP[110]
# Generator_loss:1.7877
# L1_loss:0.1865
# Discriminator_loss:0.5658
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.2417
# L1_loss:0.1751
# Discriminator_loss:0.5045
#
# EPOCH[9] - STEP[130]
# Generator_loss:0.9327
# L1_loss:0.2344
# Discriminator_loss:0.6407
#
# EPOCH[9] - STEP[140]
# Generator_loss:2.4322
# L1_loss:0.1809
# Discriminator_loss:0.3263
#
# EPOCH[9] - STEP[150]
# Generator_loss:2.4684
# L1_loss:0.2023
# Discriminator_loss:0.4079
#
# EPOCH[9] - STEP[160]
# Generator_loss:1.6806
# L1_loss:0.2027
# Discriminator_loss:0.4236
#
# EPOCH[9] - STEP[170]
# Generator_loss:1.2880
# L1_loss:0.1580
# Discriminator_loss:0.5621
#
# EPOCH[9] - STEP[180]
# Generator_loss:2.2899
# L1_loss:0.2028
# Discriminator_loss:1.4848
#
# EPOCH[9] - STEP[190]
# Generator_loss:2.3995
# L1_loss:0.1659
# Discriminator_loss:0.6645
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.1858
# L1_loss:0.1604
# Discriminator_loss:2.1062
#
# EPOCH[9] - STEP[210]
# Generator_loss:2.3356
# L1_loss:0.1396
# Discriminator_loss:0.3493
#
# EPOCH[9] - STEP[220]
# Generator_loss:1.3477
# L1_loss:0.1713
# Discriminator_loss:0.5190
#
# EPOCH[9] - STEP[230]
# Generator_loss:1.5097
# L1_loss:0.1958
# Discriminator_loss:0.8188
#
# EPOCH[9] - STEP[240]
# Generator_loss:0.7143
# L1_loss:0.1616
# Discriminator_loss:1.0783
#
# EPOCH[9] - STEP[250]
# Generator_loss:2.4361
# L1_loss:0.1849
# Discriminator_loss:0.5364
#
# EPOCH[10] - STEP[10]
# Generator_loss:2.0243
# L1_loss:0.1548
# Discriminator_loss:1.2057
#
# EPOCH[10] - STEP[20]
# Generator_loss:2.4672
# L1_loss:0.1602
# Discriminator_loss:0.6670
#
# EPOCH[10] - STEP[30]
# Generator_loss:0.8101
# L1_loss:0.2141
# Discriminator_loss:0.9902
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.0510
# L1_loss:0.1688
# Discriminator_loss:0.7103
#
# EPOCH[10] - STEP[50]
# Generator_loss:2.0283
# L1_loss:0.1896
# Discriminator_loss:0.9025
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.6549
# L1_loss:0.2248
# Discriminator_loss:0.3881
#
# EPOCH[10] - STEP[70]
# Generator_loss:2.0367
# L1_loss:0.1520
# Discriminator_loss:1.5346
#
# EPOCH[10] - STEP[80]
# Generator_loss:2.2377
# L1_loss:0.2145
# Discriminator_loss:0.2167
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.9174
# L1_loss:0.2025
# Discriminator_loss:0.6638
#
# EPOCH[10] - STEP[100]
# Generator_loss:0.2860
# L1_loss:0.1932
# Discriminator_loss:1.7896
#
# EPOCH[10] - STEP[110]
# Generator_loss:0.8982
# L1_loss:0.1874
# Discriminator_loss:0.8374
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.6356
# L1_loss:0.1968
# Discriminator_loss:0.3567
#
# EPOCH[10] - STEP[130]
# Generator_loss:2.5594
# L1_loss:0.1982
# Discriminator_loss:0.1992
#
# EPOCH[10] - STEP[140]
# Generator_loss:3.6788
# L1_loss:0.1895
# Discriminator_loss:1.4386
#
# EPOCH[10] - STEP[150]
# Generator_loss:1.5176
# L1_loss:0.2051
# Discriminator_loss:1.0739
#
# EPOCH[10] - STEP[160]
# Generator_loss:1.9406
# L1_loss:0.1623
# Discriminator_loss:1.1953
#
# EPOCH[10] - STEP[170]
# Generator_loss:2.1516
# L1_loss:0.1565
# Discriminator_loss:1.5448
#
# EPOCH[10] - STEP[180]
# Generator_loss:1.5069
# L1_loss:0.2018
# Discriminator_loss:0.4977
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.1203
# L1_loss:0.2123
# Discriminator_loss:0.9620
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.0076
# L1_loss:0.1771
# Discriminator_loss:0.7837
#
# EPOCH[10] - STEP[210]
# Generator_loss:2.3274
# L1_loss:0.1771
# Discriminator_loss:0.3083
#
# EPOCH[10] - STEP[220]
# Generator_loss:0.9823
# L1_loss:0.1832
# Discriminator_loss:1.0711
#
# EPOCH[10] - STEP[230]
# Generator_loss:3.7675
# L1_loss:0.1655
# Discriminator_loss:1.3515
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.0751
# L1_loss:0.1829
# Discriminator_loss:0.7902
#
# EPOCH[10] - STEP[250]
# Generator_loss:2.1030
# L1_loss:0.1554
# Discriminator_loss:0.4754
#
# EPOCH[11] - STEP[10]
# Generator_loss:1.8919
# L1_loss:0.2208
# Discriminator_loss:0.3942
#
# EPOCH[11] - STEP[20]
# Generator_loss:1.7793
# L1_loss:0.1990
# Discriminator_loss:0.8307
#
# EPOCH[11] - STEP[30]
# Generator_loss:2.4039
# L1_loss:0.1489
# Discriminator_loss:1.7611
#
# EPOCH[11] - STEP[40]
# Generator_loss:1.7510
# L1_loss:0.1513
# Discriminator_loss:0.9486
#
# EPOCH[11] - STEP[50]
# Generator_loss:0.7777
# L1_loss:0.1703
# Discriminator_loss:0.9935
#
# EPOCH[11] - STEP[60]
# Generator_loss:1.5993
# L1_loss:0.1721
# Discriminator_loss:0.3704
#
# EPOCH[11] - STEP[70]
# Generator_loss:2.2185
# L1_loss:0.2150
# Discriminator_loss:0.2551
#
# EPOCH[11] - STEP[80]
# Generator_loss:2.4502
# L1_loss:0.1581
# Discriminator_loss:1.0926
#
# EPOCH[11] - STEP[90]
# Generator_loss:1.1614
# L1_loss:0.1404
# Discriminator_loss:0.5350
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.3064
# L1_loss:0.1962
# Discriminator_loss:0.4283
#
# EPOCH[11] - STEP[110]
# Generator_loss:0.8611
# L1_loss:0.1813
# Discriminator_loss:1.0100
#
# EPOCH[11] - STEP[120]
# Generator_loss:2.5489
# L1_loss:0.1499
# Discriminator_loss:0.9019
#
# EPOCH[11] - STEP[130]
# Generator_loss:1.2588
# L1_loss:0.1962
# Discriminator_loss:0.5543
#
# EPOCH[11] - STEP[140]
# Generator_loss:1.8761
# L1_loss:0.1439
# Discriminator_loss:0.4504
#
# EPOCH[11] - STEP[150]
# Generator_loss:1.4878
# L1_loss:0.1550
# Discriminator_loss:0.3738
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.5207
# L1_loss:0.1443
# Discriminator_loss:0.4607
#
# EPOCH[11] - STEP[170]
# Generator_loss:0.8128
# L1_loss:0.1588
# Discriminator_loss:0.9709
#
# EPOCH[11] - STEP[180]
# Generator_loss:2.5741
# L1_loss:0.1709
# Discriminator_loss:0.7274
#
# EPOCH[11] - STEP[190]
# Generator_loss:0.7765
# L1_loss:0.1743
# Discriminator_loss:0.8358
#
# EPOCH[11] - STEP[200]
# Generator_loss:1.2748
# L1_loss:0.1377
# Discriminator_loss:1.0367
#
# EPOCH[11] - STEP[210]
# Generator_loss:1.5403
# L1_loss:0.1656
# Discriminator_loss:0.9540
#
# EPOCH[11] - STEP[220]
# Generator_loss:1.3841
# L1_loss:0.2049
# Discriminator_loss:0.4877
#
# EPOCH[11] - STEP[230]
# Generator_loss:0.5598
# L1_loss:0.1592
# Discriminator_loss:1.0689
#
# EPOCH[11] - STEP[240]
# Generator_loss:1.3565
# L1_loss:0.1719
# Discriminator_loss:0.4363
#
# EPOCH[11] - STEP[250]
# Generator_loss:1.5476
# L1_loss:0.1491
# Discriminator_loss:0.6958
#
# EPOCH[12] - STEP[10]
# Generator_loss:0.8823
# L1_loss:0.1844
# Discriminator_loss:0.8304
#
# EPOCH[12] - STEP[20]
# Generator_loss:2.5944
# L1_loss:0.1438
# Discriminator_loss:1.0684
#
# EPOCH[12] - STEP[30]
# Generator_loss:0.8615
# L1_loss:0.1804
# Discriminator_loss:1.2231
#
# EPOCH[12] - STEP[40]
# Generator_loss:3.3719
# L1_loss:0.1832
# Discriminator_loss:0.7015
#
# EPOCH[12] - STEP[50]
# Generator_loss:0.9532
# L1_loss:0.1517
# Discriminator_loss:1.3823
#
# EPOCH[12] - STEP[60]
# Generator_loss:2.2942
# L1_loss:0.1891
# Discriminator_loss:0.4396
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.7742
# L1_loss:0.1623
# Discriminator_loss:1.5385
#
# EPOCH[12] - STEP[80]
# Generator_loss:1.4252
# L1_loss:0.1910
# Discriminator_loss:0.4446
#
# EPOCH[12] - STEP[90]
# Generator_loss:0.9085
# L1_loss:0.1943
# Discriminator_loss:0.6640
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.1244
# L1_loss:0.1590
# Discriminator_loss:0.6182
#
# EPOCH[12] - STEP[110]
# Generator_loss:2.5870
# L1_loss:0.1642
# Discriminator_loss:0.3131
#
# EPOCH[12] - STEP[120]
# Generator_loss:0.8210
# L1_loss:0.1399
# Discriminator_loss:1.0075
#
# EPOCH[12] - STEP[130]
# Generator_loss:1.0465
# L1_loss:0.1709
# Discriminator_loss:0.7913
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.4880
# L1_loss:0.1731
# Discriminator_loss:0.4241
#
# EPOCH[12] - STEP[150]
# Generator_loss:1.1538
# L1_loss:0.1413
# Discriminator_loss:1.1083
#
# EPOCH[12] - STEP[160]
# Generator_loss:1.3794
# L1_loss:0.1531
# Discriminator_loss:0.9305
#
# EPOCH[12] - STEP[170]
# Generator_loss:1.3724
# L1_loss:0.2058
# Discriminator_loss:0.4433
#
# EPOCH[12] - STEP[180]
# Generator_loss:0.7778
# L1_loss:0.1703
# Discriminator_loss:0.8691
#
# EPOCH[12] - STEP[190]
# Generator_loss:1.5029
# L1_loss:0.1645
# Discriminator_loss:0.5036
#
# EPOCH[12] - STEP[200]
# Generator_loss:2.1747
# L1_loss:0.1551
# Discriminator_loss:0.3407
#
# EPOCH[12] - STEP[210]
# Generator_loss:1.1813
# L1_loss:0.2000
# Discriminator_loss:0.5282
#
# EPOCH[12] - STEP[220]
# Generator_loss:2.2256
# L1_loss:0.1941
# Discriminator_loss:0.3485
#
# EPOCH[12] - STEP[230]
# Generator_loss:1.2150
# L1_loss:0.1862
# Discriminator_loss:0.6588
#
# EPOCH[12] - STEP[240]
# Generator_loss:1.6566
# L1_loss:0.1602
# Discriminator_loss:0.6072
#
# EPOCH[12] - STEP[250]
# Generator_loss:3.3704
# L1_loss:0.1600
# Discriminator_loss:1.4943
#
# EPOCH[13] - STEP[10]
# Generator_loss:1.7786
# L1_loss:0.1740
# Discriminator_loss:0.3645
#
# EPOCH[13] - STEP[20]
# Generator_loss:1.3759
# L1_loss:0.1679
# Discriminator_loss:0.5208
#
# EPOCH[13] - STEP[30]
# Generator_loss:1.6515
# L1_loss:0.1978
# Discriminator_loss:0.7565
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.8747
# L1_loss:0.1939
# Discriminator_loss:0.7424
#
# EPOCH[13] - STEP[50]
# Generator_loss:1.5719
# L1_loss:0.1672
# Discriminator_loss:1.1805
#
# EPOCH[13] - STEP[60]
# Generator_loss:2.1186
# L1_loss:0.1635
# Discriminator_loss:0.3962
#
# EPOCH[13] - STEP[70]
# Generator_loss:2.7017
# L1_loss:0.1794
# Discriminator_loss:0.7183
#
# EPOCH[13] - STEP[80]
# Generator_loss:2.1634
# L1_loss:0.1450
# Discriminator_loss:2.1054
#
# EPOCH[13] - STEP[90]
# Generator_loss:2.3291
# L1_loss:0.1877
# Discriminator_loss:0.7124
#
# EPOCH[13] - STEP[100]
# Generator_loss:2.7806
# L1_loss:0.1523
# Discriminator_loss:0.8299
#
# EPOCH[13] - STEP[110]
# Generator_loss:1.6254
# L1_loss:0.1554
# Discriminator_loss:0.8172
#
# EPOCH[13] - STEP[120]
# Generator_loss:2.5183
# L1_loss:0.1400
# Discriminator_loss:0.7367
#
# EPOCH[13] - STEP[130]
# Generator_loss:1.9190
# L1_loss:0.1740
# Discriminator_loss:0.2906
#
# EPOCH[13] - STEP[140]
# Generator_loss:0.7406
# L1_loss:0.1702
# Discriminator_loss:0.8811
#
# EPOCH[13] - STEP[150]
# Generator_loss:1.7613
# L1_loss:0.1776
# Discriminator_loss:0.6054
#
# EPOCH[13] - STEP[160]
# Generator_loss:1.9675
# L1_loss:0.1523
# Discriminator_loss:1.3236
#
# EPOCH[13] - STEP[170]
# Generator_loss:2.4804
# L1_loss:0.1880
# Discriminator_loss:0.3404
#
# EPOCH[13] - STEP[180]
# Generator_loss:0.5595
# L1_loss:0.1624
# Discriminator_loss:1.1987
#
# EPOCH[13] - STEP[190]
# Generator_loss:1.9475
# L1_loss:0.1744
# Discriminator_loss:0.3293
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.7642
# L1_loss:0.1558
# Discriminator_loss:0.5527
#
# EPOCH[13] - STEP[210]
# Generator_loss:1.8048
# L1_loss:0.1637
# Discriminator_loss:0.6440
#
# EPOCH[13] - STEP[220]
# Generator_loss:3.1060
# L1_loss:0.2281
# Discriminator_loss:1.5168
#
# EPOCH[13] - STEP[230]
# Generator_loss:2.6547
# L1_loss:0.1198
# Discriminator_loss:1.8826
#
# EPOCH[13] - STEP[240]
# Generator_loss:1.4221
# L1_loss:0.1402
# Discriminator_loss:0.9549
#
# EPOCH[13] - STEP[250]
# ...
# L1_loss:0.1468
# Discriminator_loss:0.8419
#
# EPOCH[26] - STEP[190]
# Generator_loss:0.3606
# L1_loss:0.2227
# Discriminator_loss:1.4354
#
# EPOCH[26] - STEP[200]
# Generator_loss:2.0525
# L1_loss:0.1737
# Discriminator_loss:0.2138
#
# EPOCH[26] - STEP[210]
# Generator_loss:1.3958
# L1_loss:0.1611
# Discriminator_loss:0.4528
#
# EPOCH[26] - STEP[220]
# Generator_loss:0.8829
# L1_loss:0.1480
# Discriminator_loss:0.7639
#
# EPOCH[26] - STEP[230]
# Generator_loss:1.7413
# L1_loss:0.1212
# Discriminator_loss:0.8899
#
# EPOCH[26] - STEP[240]
# Generator_loss:0.4422
# L1_loss:0.1493
# Discriminator_loss:1.3725
#
# EPOCH[26] - STEP[250]
# Generator_loss:1.1288
# L1_loss:0.1906
# Discriminator_loss:0.5228
#
# EPOCH[27] - STEP[10]
# Generator_loss:2.4008
# L1_loss:0.1678
# Discriminator_loss:0.2958
#
# EPOCH[27] - STEP[20]
# Generator_loss:1.6742
# L1_loss:0.1587
# Discriminator_loss:0.3396
#
# EPOCH[27] - STEP[30]
# Generator_loss:0.6737
# L1_loss:0.1885
# Discriminator_loss:1.0595
#
# EPOCH[27] - STEP[40]
# Generator_loss:1.3002
# L1_loss:0.1377
# Discriminator_loss:0.6196
#
# EPOCH[27] - STEP[50]
# Generator_loss:0.4920
# L1_loss:0.1242
# Discriminator_loss:1.2810
#
# EPOCH[27] - STEP[60]
# Generator_loss:2.2884
# L1_loss:0.1354
# Discriminator_loss:0.6884
#
# EPOCH[27] - STEP[70]
# Generator_loss:1.4050
# L1_loss:0.1543
# Discriminator_loss:0.6976
#
# EPOCH[27] - STEP[80]
# Generator_loss:1.7798
# L1_loss:0.1557
# Discriminator_loss:0.5479
#
# EPOCH[27] - STEP[90]
# Generator_loss:1.8156
# L1_loss:0.1568
# Discriminator_loss:0.2732
#
# EPOCH[27] - STEP[100]
# Generator_loss:2.5117
# L1_loss:0.1412
# Discriminator_loss:0.6173
#
# EPOCH[27] - STEP[110]
# Generator_loss:3.5616
# L1_loss:0.1881
# Discriminator_loss:0.1596
#
# EPOCH[27] - STEP[120]
# Generator_loss:1.1383
# L1_loss:0.1593
# Discriminator_loss:0.5524
#
# EPOCH[27] - STEP[130]
# Generator_loss:1.9034
# L1_loss:0.1605
# Discriminator_loss:0.4377
#
# EPOCH[27] - STEP[140]
# Generator_loss:1.9239
# L1_loss:0.2613
# Discriminator_loss:0.2803
#
# EPOCH[27] - STEP[150]
# Generator_loss:1.9612
# L1_loss:0.1890
# Discriminator_loss:0.2399
#
# EPOCH[27] - STEP[160]
# Generator_loss:2.0586
# L1_loss:0.1173
# Discriminator_loss:0.8257
#
# EPOCH[27] - STEP[170]
# Generator_loss:1.0349
# L1_loss:0.1310
# Discriminator_loss:0.9169
#
# EPOCH[27] - STEP[180]
# Generator_loss:2.2610
# L1_loss:0.1686
# Discriminator_loss:0.2444
#
# EPOCH[27] - STEP[190]
# Generator_loss:1.1198
# L1_loss:0.2042
# Discriminator_loss:0.5610
#
# EPOCH[27] - STEP[200]
# Generator_loss:2.1302
# L1_loss:0.1402
# Discriminator_loss:0.6879
#
# EPOCH[27] - STEP[210]
# Generator_loss:3.3130
# L1_loss:0.1320
# Discriminator_loss:0.9703
#
# EPOCH[27] - STEP[220]
# Generator_loss:1.8067
# L1_loss:0.1311
# Discriminator_loss:0.4137
#
# EPOCH[27] - STEP[230]
# Generator_loss:0.8716
# L1_loss:0.1329
# Discriminator_loss:0.7720
#
# EPOCH[27] - STEP[240]
# Generator_loss:0.3135
# L1_loss:0.1988
# Discriminator_loss:1.8382
#
# EPOCH[27] - STEP[250]
# Generator_loss:1.3777
# L1_loss:0.1367
# Discriminator_loss:0.5469
#
# EPOCH[28] - STEP[10]
# Generator_loss:2.2290
# L1_loss:0.1463
# Discriminator_loss:0.5773
#
# EPOCH[28] - STEP[20]
# Generator_loss:1.6228
# L1_loss:0.2364
# Discriminator_loss:0.3745
#
# EPOCH[28] - STEP[30]
# Generator_loss:1.8143
# L1_loss:0.1879
# Discriminator_loss:0.8950
#
# EPOCH[28] - STEP[40]
# Generator_loss:3.3841
# L1_loss:0.1607
# Discriminator_loss:0.7294
#
# EPOCH[28] - STEP[50]
# Generator_loss:2.9161
# L1_loss:0.1336
# Discriminator_loss:0.6545
#
# EPOCH[28] - STEP[60]
# Generator_loss:1.9220
# L1_loss:0.1902
# Discriminator_loss:0.2387
#
# EPOCH[28] - STEP[70]
# Generator_loss:2.0575
# L1_loss:0.1454
# Discriminator_loss:0.9194
#
# EPOCH[28] - STEP[80]
# Generator_loss:2.8110
# L1_loss:0.1357
# Discriminator_loss:0.4604
#
# EPOCH[28] - STEP[90]
# Generator_loss:0.7632
# L1_loss:0.1727
# Discriminator_loss:0.8500
#
# EPOCH[28] - STEP[100]
# Generator_loss:1.5265
# L1_loss:0.1823
# Discriminator_loss:0.4452
#
# EPOCH[28] - STEP[110]
# Generator_loss:0.7921
# L1_loss:0.1266
# Discriminator_loss:1.1375
#
# EPOCH[28] - STEP[120]
# Generator_loss:1.7011
# L1_loss:0.1641
# Discriminator_loss:0.3602
#
# EPOCH[28] - STEP[130]
# Generator_loss:2.5165
# L1_loss:0.1435
# Discriminator_loss:0.2839
#
# EPOCH[28] - STEP[140]
# Generator_loss:1.4905
# L1_loss:0.1665
# Discriminator_loss:0.4167
#
# EPOCH[28] - STEP[150]
# Generator_loss:2.3755
# L1_loss:0.1723
# Discriminator_loss:0.4340
#
# EPOCH[28] - STEP[160]
# Generator_loss:1.7793
# L1_loss:0.1393
# Discriminator_loss:0.5439
#
# EPOCH[28] - STEP[170]
# Generator_loss:1.7113
# L1_loss:0.1611
# Discriminator_loss:0.6144
#
# EPOCH[28] - STEP[180]
# Generator_loss:2.5779
# L1_loss:0.1753
# Discriminator_loss:0.3021
#
# EPOCH[28] - STEP[190]
# Generator_loss:3.3738
# L1_loss:0.1525
# Discriminator_loss:0.3690
#
# EPOCH[28] - STEP[200]
# Generator_loss:0.4910
# L1_loss:0.1466
# Discriminator_loss:1.2883
#
# EPOCH[28] - STEP[210]
# Generator_loss:4.4692
# L1_loss:0.1941
# Discriminator_loss:0.0733
#
# EPOCH[28] - STEP[220]
# Generator_loss:1.0693
# L1_loss:0.1480
# Discriminator_loss:0.5981
#
# EPOCH[28] - STEP[230]
# Generator_loss:1.4215
# L1_loss:0.1679
# Discriminator_loss:0.4886
#
# EPOCH[28] - STEP[240]
# Generator_loss:2.5553
# L1_loss:0.1746
# Discriminator_loss:0.4174
#
# EPOCH[28] - STEP[250]
# Generator_loss:1.0995
# L1_loss:0.1555
# Discriminator_loss:0.8878
#
# EPOCH[29] - STEP[10]
# Generator_loss:2.7830
# L1_loss:0.1333
# Discriminator_loss:1.8321
#
# EPOCH[29] - STEP[20]
# Generator_loss:2.5569
# L1_loss:0.1696
# Discriminator_loss:0.6801
#
# EPOCH[29] - STEP[30]
# Generator_loss:3.0153
# L1_loss:0.1543
# Discriminator_loss:0.8488
#
# EPOCH[29] - STEP[40]
# Generator_loss:2.4703
# L1_loss:0.1403
# Discriminator_loss:0.4408
#
# EPOCH[29] - STEP[50]
# Generator_loss:2.0172
# L1_loss:0.1837
# Discriminator_loss:0.3501
#
# EPOCH[29] - STEP[60]
# Generator_loss:2.2231
# L1_loss:0.1493
# Discriminator_loss:0.4317
#
# EPOCH[29] - STEP[70]
# Generator_loss:2.1279
# L1_loss:0.1468
# Discriminator_loss:0.5587
#
# EPOCH[29] - STEP[80]
# Generator_loss:1.8554
# L1_loss:0.1515
# Discriminator_loss:0.5901
#
# EPOCH[29] - STEP[90]
# Generator_loss:3.2300
# L1_loss:0.2013
# Discriminator_loss:0.0723
#
# EPOCH[29] - STEP[100]
# Generator_loss:3.0855
# L1_loss:0.1471
# Discriminator_loss:0.2740
#
# EPOCH[29] - STEP[110]
# Generator_loss:2.4219
# L1_loss:0.1597
# Discriminator_loss:0.2425
#
# EPOCH[29] - STEP[120]
# Generator_loss:1.7012
# L1_loss:0.1345
# Discriminator_loss:0.2966
#
# EPOCH[29] - STEP[130]
# Generator_loss:1.7193
# L1_loss:0.1469
# Discriminator_loss:1.0562
#
# EPOCH[29] - STEP[140]
# Generator_loss:3.1791
# L1_loss:0.1875
# Discriminator_loss:0.3180
#
# EPOCH[29] - STEP[150]
# Generator_loss:0.7516
# L1_loss:0.1297
# Discriminator_loss:1.1710
#
# EPOCH[29] - STEP[160]
# Generator_loss:3.6450
# L1_loss:0.1852
# Discriminator_loss:0.1138
#
# EPOCH[29] - STEP[170]
# Generator_loss:3.7727
# L1_loss:0.1744
# Discriminator_loss:0.5228
#
# EPOCH[29] - STEP[180]
# Generator_loss:3.7966
# L1_loss:0.1706
# Discriminator_loss:1.4359
#
# EPOCH[29] - STEP[190]
# Generator_loss:1.0584
# L1_loss:0.1406
# Discriminator_loss:0.6622
#
# EPOCH[29] - STEP[200]
# Generator_loss:2.2521
# L1_loss:0.1457
# Discriminator_loss:0.6190
#
# EPOCH[29] - STEP[210]
# Generator_loss:0.8553
# L1_loss:0.1562
# Discriminator_loss:0.7149
#
# EPOCH[29] - STEP[220]
# Generator_loss:3.7374
# L1_loss:0.1330
# Discriminator_loss:1.7201
#
# EPOCH[29] - STEP[230]
# Generator_loss:2.2552
# L1_loss:0.1293
# Discriminator_loss:1.0120
#
# EPOCH[29] - STEP[240]
# Generator_loss:1.8269
# L1_loss:0.1391
# Discriminator_loss:0.8036
#
# EPOCH[29] - STEP[250]
# Generator_loss:3.4954
# L1_loss:0.1684
# Discriminator_loss:0.3043
#
# EPOCH[30] - STEP[10]
# Generator_loss:3.9429
# L1_loss:0.2202
# Discriminator_loss:0.0607
#
# EPOCH[30] - STEP[20]
# Generator_loss:2.5741
# L1_loss:0.1340
# Discriminator_loss:0.8289
#
# EPOCH[30] - STEP[30]
# Generator_loss:1.9356
# L1_loss:0.1540
# Discriminator_loss:0.4728
#
# EPOCH[30] - STEP[40]
# Generator_loss:3.4961
# L1_loss:0.1170
# Discriminator_loss:1.6816
#
# EPOCH[30] - STEP[50]
# Generator_loss:2.2135
# L1_loss:0.1431
# Discriminator_loss:0.3576
#
# EPOCH[30] - STEP[60]
# Generator_loss:1.7579
# L1_loss:0.1568
# Discriminator_loss:0.3704
#
# EPOCH[30] - STEP[70]
# Generator_loss:1.6991
# L1_loss:0.1694
# Discriminator_loss:0.4698
#
# EPOCH[30] - STEP[80]
# Generator_loss:1.1891
# L1_loss:0.1186
# Discriminator_loss:1.3191
#
# EPOCH[30] - STEP[90]
# Generator_loss:3.3754
# L1_loss:0.1513
# Discriminator_loss:0.6560
#
# EPOCH[30] - STEP[100]
# Generator_loss:3.3183
# L1_loss:0.1207
# Discriminator_loss:0.7232
#
# EPOCH[30] - STEP[110]
# Generator_loss:3.3284
# L1_loss:0.1337
# Discriminator_loss:0.7915
#
# EPOCH[30] - STEP[120]
# Generator_loss:1.6335
# L1_loss:0.1385
# Discriminator_loss:0.3403
#
# EPOCH[30] - STEP[130]
# Generator_loss:2.2754
# L1_loss:0.1413
# Discriminator_loss:0.3311
#
# EPOCH[30] - STEP[140]
# Generator_loss:2.3885
# L1_loss:0.1489
# Discriminator_loss:0.2881
#
# EPOCH[30] - STEP[150]
# Generator_loss:1.4160
# L1_loss:0.2092
# Discriminator_loss:0.4249
#
# EPOCH[30] - STEP[160]
# Generator_loss:2.1667
# L1_loss:0.1492
# Discriminator_loss:0.8664
#
# EPOCH[30] - STEP[170]
# Generator_loss:2.1396
# L1_loss:0.1543
# Discriminator_loss:0.5525
#
# EPOCH[30] - STEP[180]
# Generator_loss:0.4015
# L1_loss:0.1528
# Discriminator_loss:1.4560
#
# EPOCH[30] - STEP[190]
# Generator_loss:4.1693
# L1_loss:0.1315
# Discriminator_loss:1.8850
#
# EPOCH[30] - STEP[200]
# Generator_loss:4.0737
# L1_loss:0.2198
# Discriminator_loss:0.1310
#
# EPOCH[30] - STEP[210]
# Generator_loss:2.8597
# L1_loss:0.1471
# Discriminator_loss:0.4949
#
# EPOCH[30] - STEP[220]
# Generator_loss:3.1502
# L1_loss:0.1385
# Discriminator_loss:0.3623
#
# EPOCH[30] - STEP[230]
# Generator_loss:1.0545
# L1_loss:0.1725
# Discriminator_loss:0.7597
#
# EPOCH[30] - STEP[240]
# Generator_loss:2.9622
# L1_loss:0.1370
# Discriminator_loss:0.7538
#
# EPOCH[30] - STEP[250]
# Generator_loss:1.3807
# L1_loss:0.1667
# Discriminator_loss:0.4498

# %% [markdown]
# ## 평가

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# ## 회고
# #### 생각보다 결과가 좋지못했다 augmentation을 했음에도 데이터셋의 양이 적었던건지 모델설계를 적절하게 하지않았는지 확인해야 겠다.
